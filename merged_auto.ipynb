# %%
import pandas as pd

# %% [markdown]
# # AutoListData

# %%
path = ('AutoListData')
auto_df= pd.read_csv(path)

# %%
auto_df.head()
# Out:
#                  vin        display_color  year     make       model    price  \
# 0  WP1AA2A59HLB04454   Jet Black Metallic  2017  Porsche       Macan  $39,499
# 1  1FTEX1EP1JFB61095         Shadow Black  2018     Ford       F-150  $34,999
# 2  3GKALPEV8KL250380  Red Quartz Tintcoat  2019      GMC     Terrain  $24,097
# 3  2C3CDZFJ2KH684574    Sublime Pearlcoat  2019    Dodge  Challenger  $46,299
# 4  5FNYF6H0XHB090862  White Diamond Pearl  2017    Honda       Pilot  $28,299
#
#         mileage     city condition                  dealer_name state  \
# 0  46,216 Miles    Miami      used      Florida Fine Cars Miami    FL
# 1  32,170 Miles    Miami      used      Florida Fine Cars Miami    FL
# 2  48,618 Miles  Spokane      used       Avis Car Sales Spokane    WA
# 3   9,981 Miles  Margate      used  Florida Fine Cars - Margate    FL
# 4  69,243 Miles  Margate      used  Florida Fine Cars - Margate    FL
#
#             trim body_style
# 0           Base        suv
# 1            XLT      truck
# 2            SLT        suv
# 3  R/T Scat Pack      coupe
# 4          Elite        suv

# %%
# auto_df['price']=auto_df['price'].str.replace(',','').str.replace('$','').astype(int)
auto_df['model']=auto_df['model'].str.replace('-','')
auto_df['mileage']=auto_df['mileage'].fillna(0)
auto_df['mileage']=auto_df['mileage'].str.replace('New','0').str.replace(',','').str.replace('Miles','')
auto_df['model']=auto_df['model'].str.replace('Pickup 1500','1500')
auto_df
# Out:
#                     vin                       display_color  year       make  \
# 0     WP1AA2A59HLB04454                  Jet Black Metallic  2017    Porsche
# 1     1FTEX1EP1JFB61095                        Shadow Black  2018       Ford
# 2     3GKALPEV8KL250380                 Red Quartz Tintcoat  2019        GMC
# 3     2C3CDZFJ2KH684574                   Sublime Pearlcoat  2019      Dodge
# 4     5FNYF6H0XHB090862                 White Diamond Pearl  2017      Honda
# ...                 ...                                 ...   ...        ...
# 4852  1C4AJWAG5JL854658                                Gray  2018       Jeep
# 4853  1C6SRFJT2MN823734  Granite Crystal Metallic Clearcoat  2021        Ram
# 4854  1G11Z5SA1KU137577               Mosaic Black Metallic  2019  Chevrolet
# 4855  1FM5K8GC1LGA11112                            Magnetic  2020       Ford
# 4856  1HGCV1F18JA042692               Champagne Frost Pearl  2018      Honda
#
#            model    price mileage          city condition  \
# 0          Macan  $39,499  46216          Miami      used
# 1           F150  $34,999  32170          Miami      used
# 2        Terrain  $24,097  48618        Spokane      used
# 3     Challenger  $46,299   9981        Margate      used
# 4          Pilot  $28,299  69243        Margate      used
# ...          ...      ...     ...           ...       ...
# 4852    Wrangler  $34,999  28738       Missoula      used
# 4853        1500  $57,005       0    Huntsville       new
# 4854      Impala  $21,600  54839   Philadelphia      used
# 4855    Explorer  $50,999  21635       Stafford      used
# 4856      Accord  $22,299  31361      Santa Ana      used
#
#                           dealer_name state           trim body_style
# 0             Florida Fine Cars Miami    FL           Base        suv
# 1             Florida Fine Cars Miami    FL            XLT      truck
# 2              Avis Car Sales Spokane    WA            SLT        suv
# 3         Florida Fine Cars - Margate    FL  R/T Scat Pack      coupe
# 4         Florida Fine Cars - Margate    FL          Elite        suv
# ...                               ...   ...            ...        ...
# 4852  Northwest Motorsport - Missoula    MT          Sport        suv
# 4853  Wischnewsky Dodge Chrysler Jeep    TX        Laramie      truck
# 4854     Hertz Car Sales Philadelphia    PA             LT      sedan
# 4855                Texas Direct Auto    TX             ST        suv
# 4856        California Motors Direct1    CA             LX      sedan
#
# [4857 rows x 13 columns]

# %%
auto_df=auto_df.sort_values(['year'])
auto_df
# Out:
#                     vin             display_color  year           make  \
# 4748  WDBFA68F7YF191944                     Black  2000  Mercedes-Benz
# 3084  1G1YY22G725106798                     Black  2002      Chevrolet
# 4221  1G1YY22G835128178  Dark Cherry Red Metallic  2003      Chevrolet
# 4573  1FTYR14UX3PA59502    Arizona Beige Metallic  2003           Ford
# 1983  JHMAP11433T002141      Silverstone Metallic  2003          Honda
# ...                 ...                       ...   ...            ...
# 3075  1G1FW6S0XN4110877     Mosaic Black Metallic  2022      Chevrolet
# 4725  1G1FX6S01N4105807      Bright Blue Metallic  2022      Chevrolet
# 2744  5XXG64J28NG108487                       Red  2022            Kia
# 3353  5NPEJ4J20NH136259                     White  2022        Hyundai
# 2568  KNDPN3AC2N7001496                Steel Gray  2022            Kia
#
#          model    price  mileage           city condition  \
# 4748   SLClass  $14,998   70574      Minnetonka      used
# 3084  Corvette  $19,993   59204          Toledo      used
# 4221  Corvette  $28,100   26244            Katy      used
# 4573    Ranger   $5,466  167113       Thorndale      used
# 1983     S2000  $34,189   15815     Catonsville      used
# ...        ...      ...      ...            ...       ...
# 3075   Bolt EV  $32,935        0         Fenton       new
# 4725   Bolt EV  $35,685        0         Fenton       new
# 2744        K5  $27,712        0      Englewood       new
# 3353    Sonata  $32,934        0    Friendswood       new
# 2568  Sportage  $34,850        0  Coral Springs       new
#
#                        dealer_name state      trim   body_style
# 4748          Sears Imported Autos    MN    SL 500  convertible
# 3084  Yark Chrysler Jeep Dodge Ram    OH      Base        coupe
# 4221                Toyota of Katy    TX      Base        coupe
# 4573                    Del Toyota    PA        XL        truck
# 1983            BMW of Catonsville    MD      Base  convertible
# ...                            ...   ...       ...          ...
# 3075          Jim Butler Chevrolet    MO       1LT    hatchback
# 4725          Jim Butler Chevrolet    MO       2LT    hatchback
# 2744                  Arapahoe Kia    CO   GT-Line        sedan
# 3353              Big Star Hyundai    TX  SEL Plus        sedan
# 2568             Coral Springs Kia    FL        EX          suv
#
# [4857 rows x 13 columns]

# %% [markdown]
# # USA_cars_datasets

# %%
path2 = 'USA_cars_datasets.csv'
auto2_df = pd.read_csv(path2)
# Out:
# C:\Users\Sharon\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (1,2,5,6,8,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
auto2_df
# Out:
#            price      brand    model    year   mileage   color  \
# 0         6300.0     toyota  cruiser  2008.0  274117.0   black
# 1         2899.0       ford       se  2011.0  190552.0  silver
# 2         5350.0      dodge      mpv  2018.0   39590.0  silver
# 3        25000.0       ford     door  2014.0   64146.0    blue
# 4        27700.0  chevrolet     1500  2018.0    6654.0     red
# ...          ...        ...      ...     ...       ...     ...
# 1048570      NaN        NaN      NaN     NaN       NaN     NaN
# 1048571      NaN        NaN      NaN     NaN       NaN     NaN
# 1048572      NaN        NaN      NaN     NaN       NaN     NaN
# 1048573      NaN        NaN      NaN     NaN       NaN     NaN
# 1048574      NaN        NaN      NaN     NaN       NaN     NaN
#
#                          vin          lot       state country
# 0          jtezu11f88k007763  159348797.0  new jersey     usa
# 1          2fmdk3gc4bbb02217  166951262.0   tennessee     usa
# 2          3c4pdcgg5jt346413  167655728.0     georgia     usa
# 3          1ftfw1et4efc23745  167753855.0    virginia     usa
# 4          3gcpcrec2jg473991  167763266.0     florida     usa
# ...                      ...          ...         ...     ...
# 1048570                  NaN          NaN         NaN     NaN
# 1048571                  NaN          NaN         NaN     NaN
# 1048572                  NaN          NaN         NaN     NaN
# 1048573                  NaN          NaN         NaN     NaN
# 1048574                  NaN          NaN         NaN     NaN
#
# [1048575 rows x 10 columns]

# %%
auto2_df.isnull().sum()
# Out:
# price      1046083
# brand      1046083
# model      1046083
# year       1046083
# mileage    1046083
# color      1046083
# vin        1046083
# lot        1046083
# state      1046083
# country    1046083
# dtype: int64

# %%
auto3_df=auto2_df.dropna()
auto3_df
# Out:
#         price      brand    model    year   mileage   color  \
# 0      6300.0     toyota  cruiser  2008.0  274117.0   black
# 1      2899.0       ford       se  2011.0  190552.0  silver
# 2      5350.0      dodge      mpv  2018.0   39590.0  silver
# 3     25000.0       ford     door  2014.0   64146.0    blue
# 4     27700.0  chevrolet     1500  2018.0    6654.0     red
# ...       ...        ...      ...     ...       ...     ...
# 2487   7800.0     nissan    versa  2019.0   23609.0     red
# 2488   9200.0     nissan    versa  2018.0   34553.0  silver
# 2489   9200.0     nissan    versa  2018.0   31594.0  silver
# 2490   9200.0     nissan    versa  2018.0   32557.0   black
# 2491   9200.0     nissan    versa  2018.0   31371.0  silver
#
#                       vin          lot       state country
# 0       jtezu11f88k007763  159348797.0  new jersey     usa
# 1       2fmdk3gc4bbb02217  166951262.0   tennessee     usa
# 2       3c4pdcgg5jt346413  167655728.0     georgia     usa
# 3       1ftfw1et4efc23745  167753855.0    virginia     usa
# 4       3gcpcrec2jg473991  167763266.0     florida     usa
# ...                   ...          ...         ...     ...
# 2487    3n1cn7ap9kl880319  167722715.0  california     usa
# 2488    3n1cn7ap5jl884088  167762225.0     florida     usa
# 2489    3n1cn7ap9jl884191  167762226.0     florida     usa
# 2490    3n1cn7ap3jl883263  167762227.0     florida     usa
# 2491    3n1cn7ap4jl884311  167762228.0     florida     usa
#
# [2492 rows x 10 columns]

# %%
auto3_df['price'].dtype
# Out:
# dtype('float64')

# %%
auto3_df=auto3_df.sort_values(['year'])
auto3_df
# Out:
#         price      brand    model    year   mileage  color  \
# 32    29800.0  chevrolet   camaro  1973.0   46226.0    red
# 404      25.0       ford     door  1984.0   41577.0  white
# 544       0.0        gmc     door  1993.0       0.0   blue
# 361      25.0       ford   pickup  1994.0  206162.0  white
# 321       0.0       ford  chassis  1994.0       0.0  green
# ...       ...        ...      ...     ...       ...    ...
# 222   16300.0  chevrolet     trax  2020.0   18221.0  white
# 225   45500.0  chevrolet    tahoe  2020.0   13885.0  white
# 1635  20600.0       ford   fusion  2020.0   17858.0  black
# 1669  23400.0       ford   fusion  2020.0    2452.0   gray
# 1697  25200.0       ford   escape  2020.0       7.0  black
#
#                       vin          lot         state country
# 32          1q87t3n166389  167763370.0  pennsylvania     usa
# 404     2ftcf15y9eca14589  167611661.0      arkansas     usa
# 544     1gkfk16k5pj701631  167358601.0      colorado     usa
# 361     1ftdf15y2rnb12612  167361489.0       georgia     usa
# 321     1fdee14n7rha47894  167359174.0    california     usa
# ...                   ...          ...           ...     ...
# 222     3gncjlsb4ll149763  167766003.0       georgia     usa
# 225     1gnscbkc6lr159535  167766009.0       georgia     usa
# 1635    3fa6p0cd8lr115427  167570001.0      virginia     usa
# 1669    3fa6p0hd6lr110753  167749593.0      michigan     usa
# 1697    1fmcu9f61lua48374  167751305.0      virginia     usa
#
# [2492 rows x 10 columns]

# %%
auto3_df['price']=auto3_df['price'].astype(int)
auto3_df['year']=auto3_df['year'].astype(int)
auto3_df['mileage']=auto3_df['mileage'].astype(int)
auto3_df['lot']=auto3_df['lot'].astype(int)
auto3_df
# Out:
#       price      brand     model  year  mileage   color                  vin  \
# 32    29800  chevrolet    camaro  1973    46226     red        1q87t3n166389
# 361      25       ford    pickup  1994   206162   white    1ftdf15y2rnb12612
# 321       0       ford   chassis  1994        0   green    1fdee14n7rha47894
# 495       0       ford    pickup  1996   252588     red    1ftef15n0tlc14455
# 292       0  chevrolet    pickup  1998   258631    gray    1gccs1445wk226994
# ...     ...        ...       ...   ...      ...     ...                  ...
# 2315  15000     nissan    altima  2020    14320    blue    1n4bl4cv4lc134145
# 1222  14300       ford    fusion  2020     6975  silver    3fa6p0d98lr117690
# 805   28300  chevrolet  colorado  2020    13886  silver    1gcgtcen7l1101496
# 425   55600      lexus        gx  2020     8186  silver    jtjam7bx4l5251250
# 1697  25200       ford    escape  2020        7   black    1fmcu9f61lua48374
#
#             lot         state country
# 32    167763370  pennsylvania     usa
# 361   167361489       georgia     usa
# 321   167359174    california     usa
# 495   167357804      oklahoma     usa
# 292   167417659         texas     usa
# ...         ...           ...     ...
# 2315  167656212          ohio     usa
# 1222  167722616    california     usa
# 805   167805497       indiana     usa
# 425   167605747       florida     usa
# 1697  167751305      virginia     usa
#
# [1841 rows x 10 columns]

# %%
# Dropping my duplicated data and checking that the data has been shortened.
auto3_df.drop(auto3_df[auto3_df['model']=='door'].index,inplace=True)
# auto3_df.drop(auto3_df[auto3_df['price']=='0.0'].index,inplace=True)
# auto3_df.sort_values(['price'])
auto3_df=auto3_df.sort_values(['year'])
auto3_df
# Out:
#       price      brand    model  year  mileage   color                  vin  \
# 32    29800  chevrolet   camaro  1973    46226     red        1q87t3n166389
# 361      25       ford   pickup  1994   206162   white    1ftdf15y2rnb12612
# 321       0       ford  chassis  1994        0   green    1fdee14n7rha47894
# 495       0       ford   pickup  1996   252588     red    1ftef15n0tlc14455
# 292       0  chevrolet   pickup  1998   258631    gray    1gccs1445wk226994
# ...     ...        ...      ...   ...      ...     ...                  ...
# 225   45500  chevrolet    tahoe  2020    13885   white    1gnscbkc6lr159535
# 2334  18000     nissan    rogue  2020    12748   black    jn8at2mt4lw003761
# 1635  20600       ford   fusion  2020    17858   black    3fa6p0cd8lr115427
# 2332  19800     nissan    rogue  2020    14850  silver    knmat2mv2lp511637
# 1697  25200       ford   escape  2020        7   black    1fmcu9f61lua48374
#
#             lot         state country
# 32    167763370  pennsylvania     usa
# 361   167361489       georgia     usa
# 321   167359174    california     usa
# 495   167357804      oklahoma     usa
# 292   167417659         texas     usa
# ...         ...           ...     ...
# 225   167766009       georgia     usa
# 2334  167614833     minnesota     usa
# 1635  167570001      virginia     usa
# 2332  167614830     minnesota     usa
# 1697  167751305      virginia     usa
#
# [1841 rows x 10 columns]

# %%
auto3_df['price'].dtype
# Out:
# dtype('int32')

# %%
auto3_df.drop(auto3_df[auto3_df['price']==0].index,inplace=True)
auto3_df
# Out:
#       price      brand   model  year  mileage   color                  vin  \
# 32    29800  chevrolet  camaro  1973    46226     red        1q87t3n166389
# 361      25       ford  pickup  1994   206162   white    1ftdf15y2rnb12612
# 362     950       ford      pk  2001   229886     red    1ftrx17w41nb80705
# 446      75       ford  pickup  2001   295780    gold    1ftrw08l61kc05834
# 200    5000      dodge  pickup  2001   109360   white    1b7hc16x01s213315
# ...     ...        ...     ...   ...      ...     ...                  ...
# 225   45500  chevrolet   tahoe  2020    13885   white    1gnscbkc6lr159535
# 2334  18000     nissan   rogue  2020    12748   black    jn8at2mt4lw003761
# 1635  20600       ford  fusion  2020    17858   black    3fa6p0cd8lr115427
# 2332  19800     nissan   rogue  2020    14850  silver    knmat2mv2lp511637
# 1697  25200       ford  escape  2020        7   black    1fmcu9f61lua48374
#
#             lot         state country
# 32    167763370  pennsylvania     usa
# 361   167361489       georgia     usa
# 362   167611176      illinois     usa
# 446   167357592      arkansas     usa
# 200   167756836       georgia     usa
# ...         ...           ...     ...
# 225   167766009       georgia     usa
# 2334  167614833     minnesota     usa
# 1635  167570001      virginia     usa
# 2332  167614830     minnesota     usa
# 1697  167751305      virginia     usa
#
# [1829 rows x 10 columns]

# %%
auto3_df
# Out:
#       price      brand     model  year  mileage   color                  vin  \
# 32    29800  chevrolet    camaro  1973    46226     red        1q87t3n166389
# 361      25       ford    pickup  1994   206162   white    1ftdf15y2rnb12612
# 321       0       ford   chassis  1994        0   green    1fdee14n7rha47894
# 495       0       ford    pickup  1996   252588     red    1ftef15n0tlc14455
# 292       0  chevrolet    pickup  1998   258631    gray    1gccs1445wk226994
# ...     ...        ...       ...   ...      ...     ...                  ...
# 2315  15000     nissan    altima  2020    14320    blue    1n4bl4cv4lc134145
# 1222  14300       ford    fusion  2020     6975  silver    3fa6p0d98lr117690
# 805   28300  chevrolet  colorado  2020    13886  silver    1gcgtcen7l1101496
# 425   55600      lexus        gx  2020     8186  silver    jtjam7bx4l5251250
# 1697  25200       ford    escape  2020        7   black    1fmcu9f61lua48374
#
#             lot         state country
# 32    167763370  pennsylvania     usa
# 361   167361489       georgia     usa
# 321   167359174    california     usa
# 495   167357804      oklahoma     usa
# 292   167417659         texas     usa
# ...         ...           ...     ...
# 2315  167656212          ohio     usa
# 1222  167722616    california     usa
# 805   167805497       indiana     usa
# 425   167605747       florida     usa
# 1697  167751305      virginia     usa
#
# [1841 rows x 10 columns]

# %%
auto3_df.drop(auto3_df[auto3_df['price']=='0.0'].index,inplace=True)
auto3_df
# Out:
# C:\Users\Sharon\anaconda3\envs\PythonData\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
#       price      brand     model  year  mileage   color                  vin  \
# 32    29800  chevrolet    camaro  1973    46226     red        1q87t3n166389
# 361      25       ford    pickup  1994   206162   white    1ftdf15y2rnb12612
# 321       0       ford   chassis  1994        0   green    1fdee14n7rha47894
# 495       0       ford    pickup  1996   252588     red    1ftef15n0tlc14455
# 292       0  chevrolet    pickup  1998   258631    gray    1gccs1445wk226994
# ...     ...        ...       ...   ...      ...     ...                  ...
# 2315  15000     nissan    altima  2020    14320    blue    1n4bl4cv4lc134145
# 1222  14300       ford    fusion  2020     6975  silver    3fa6p0d98lr117690
# 805   28300  chevrolet  colorado  2020    13886  silver    1gcgtcen7l1101496
# 425   55600      lexus        gx  2020     8186  silver    jtjam7bx4l5251250
# 1697  25200       ford    escape  2020        7   black    1fmcu9f61lua48374
#
#             lot         state country
# 32    167763370  pennsylvania     usa
# 361   167361489       georgia     usa
# 321   167359174    california     usa
# 495   167357804      oklahoma     usa
# 292   167417659         texas     usa
# ...         ...           ...     ...
# 2315  167656212          ohio     usa
# 1222  167722616    california     usa
# 805   167805497       indiana     usa
# 425   167605747       florida     usa
# 1697  167751305      virginia     usa
#
# [1841 rows x 10 columns]

# %%
auto3_df.drop(auto3_df[auto3_df['year']<=1994].index,inplace=True)
auto3_df
# Out:
#       price      brand   model  year  mileage   color                  vin  \
# 362     950       ford      pk  2001   229886     red    1ftrx17w41nb80705
# 446      75       ford  pickup  2001   295780    gold    1ftrw08l61kc05834
# 200    5000      dodge  pickup  2001   109360   white    1b7hc16x01s213315
# 185    1400      dodge      pk  2002   185460   black    1b7hg38n62s587845
# 39     7000       ford      pk  2003   176567   white    1ftnx20p73ed69682
# ...     ...        ...     ...   ...      ...     ...                  ...
# 225   45500  chevrolet   tahoe  2020    13885   white    1gnscbkc6lr159535
# 2334  18000     nissan   rogue  2020    12748   black    jn8at2mt4lw003761
# 1635  20600       ford  fusion  2020    17858   black    3fa6p0cd8lr115427
# 2332  19800     nissan   rogue  2020    14850  silver    knmat2mv2lp511637
# 1697  25200       ford  escape  2020        7   black    1fmcu9f61lua48374
#
#             lot      state country
# 362   167611176   illinois     usa
# 446   167357592   arkansas     usa
# 200   167756836    georgia     usa
# 185   167756423   michigan     usa
# 39    167754187  tennessee     usa
# ...         ...        ...     ...
# 225   167766009    georgia     usa
# 2334  167614833  minnesota     usa
# 1635  167570001   virginia     usa
# 2332  167614830  minnesota     usa
# 1697  167751305   virginia     usa
#
# [1827 rows x 10 columns]

# %%
auto3_clean_df = auto3_df.rename(columns={
    'vin':'vin',
    'color':'display_color',
    'year':'year',
    'brand':'make',
    'model':'model',
    'price':'price',
    'mileage':'mileage',
    'lot':'dealer_name',
    'state':'state',
})
auto3_clean_df
# Out:
#       price       make   model  year  mileage display_color  \
# 362     950       ford      pk  2001   229886           red
# 446      75       ford  pickup  2001   295780          gold
# 200    5000      dodge  pickup  2001   109360         white
# 185    1400      dodge      pk  2002   185460         black
# 39     7000       ford      pk  2003   176567         white
# ...     ...        ...     ...   ...      ...           ...
# 225   45500  chevrolet   tahoe  2020    13885         white
# 2334  18000     nissan   rogue  2020    12748         black
# 1635  20600       ford  fusion  2020    17858         black
# 2332  19800     nissan   rogue  2020    14850        silver
# 1697  25200       ford  escape  2020        7         black
#
#                       vin  dealer_name      state country
# 362     1ftrx17w41nb80705    167611176   illinois     usa
# 446     1ftrw08l61kc05834    167357592   arkansas     usa
# 200     1b7hc16x01s213315    167756836    georgia     usa
# 185     1b7hg38n62s587845    167756423   michigan     usa
# 39      1ftnx20p73ed69682    167754187  tennessee     usa
# ...                   ...          ...        ...     ...
# 225     1gnscbkc6lr159535    167766009    georgia     usa
# 2334    jn8at2mt4lw003761    167614833  minnesota     usa
# 1635    3fa6p0cd8lr115427    167570001   virginia     usa
# 2332    knmat2mv2lp511637    167614830  minnesota     usa
# 1697    1fmcu9f61lua48374    167751305   virginia     usa
#
# [1827 rows x 10 columns]

# %%
auto3_clean_df['trim']='N/A'
auto3_clean_df['body_style']='N/A'
auto3_clean_df['condition']='used'
auto3_clean_df['city']='N/A'
auto3_clean_df=auto3_clean_df.drop(['country'],axis=1)
auto3_clean_df
# Out:
#       price       make   model  year  mileage display_color  \
# 362     950       ford      pk  2001   229886           red
# 446      75       ford  pickup  2001   295780          gold
# 200    5000      dodge  pickup  2001   109360         white
# 185    1400      dodge      pk  2002   185460         black
# 39     7000       ford      pk  2003   176567         white
# ...     ...        ...     ...   ...      ...           ...
# 225   45500  chevrolet   tahoe  2020    13885         white
# 2334  18000     nissan   rogue  2020    12748         black
# 1635  20600       ford  fusion  2020    17858         black
# 2332  19800     nissan   rogue  2020    14850        silver
# 1697  25200       ford  escape  2020        7         black
#
#                       vin  dealer_name      state trim body_style condition  \
# 362     1ftrx17w41nb80705    167611176   illinois  N/A        N/A      used
# 446     1ftrw08l61kc05834    167357592   arkansas  N/A        N/A      used
# 200     1b7hc16x01s213315    167756836    georgia  N/A        N/A      used
# 185     1b7hg38n62s587845    167756423   michigan  N/A        N/A      used
# 39      1ftnx20p73ed69682    167754187  tennessee  N/A        N/A      used
# ...                   ...          ...        ...  ...        ...       ...
# 225     1gnscbkc6lr159535    167766009    georgia  N/A        N/A      used
# 2334    jn8at2mt4lw003761    167614833  minnesota  N/A        N/A      used
# 1635    3fa6p0cd8lr115427    167570001   virginia  N/A        N/A      used
# 2332    knmat2mv2lp511637    167614830  minnesota  N/A        N/A      used
# 1697    1fmcu9f61lua48374    167751305   virginia  N/A        N/A      used
#
#      city
# 362   N/A
# 446   N/A
# 200   N/A
# 185   N/A
# 39    N/A
# ...   ...
# 225   N/A
# 2334  N/A
# 1635  N/A
# 2332  N/A
# 1697  N/A
#
# [1827 rows x 13 columns]

# %%
pd.concat([auto3_clean_df, auto_df])
# Out:
#         price       make     model  year mileage          display_color  \
# 362       950       ford        pk  2001  229886                    red
# 446        75       ford    pickup  2001  295780                   gold
# 200      5000      dodge    pickup  2001  109360                  white
# 185      1400      dodge        pk  2002  185460                  black
# 39       7000       ford        pk  2003  176567                  white
# ...       ...        ...       ...   ...     ...                    ...
# 3075  $32,935  Chevrolet   Bolt EV  2022       0  Mosaic Black Metallic
# 4725  $35,685  Chevrolet   Bolt EV  2022       0   Bright Blue Metallic
# 2744  $27,712        Kia        K5  2022       0                    Red
# 3353  $32,934    Hyundai    Sonata  2022       0                  White
# 2568  $34,850        Kia  Sportage  2022       0             Steel Gray
#
#                       vin           dealer_name      state      trim  \
# 362     1ftrx17w41nb80705             167611176   illinois       N/A
# 446     1ftrw08l61kc05834             167357592   arkansas       N/A
# 200     1b7hc16x01s213315             167756836    georgia       N/A
# 185     1b7hg38n62s587845             167756423   michigan       N/A
# 39      1ftnx20p73ed69682             167754187  tennessee       N/A
# ...                   ...                   ...        ...       ...
# 3075    1G1FW6S0XN4110877  Jim Butler Chevrolet         MO       1LT
# 4725    1G1FX6S01N4105807  Jim Butler Chevrolet         MO       2LT
# 2744    5XXG64J28NG108487          Arapahoe Kia         CO   GT-Line
# 3353    5NPEJ4J20NH136259      Big Star Hyundai         TX  SEL Plus
# 2568    KNDPN3AC2N7001496     Coral Springs Kia         FL        EX
#
#      body_style condition           city
# 362         N/A      used            N/A
# 446         N/A      used            N/A
# 200         N/A      used            N/A
# 185         N/A      used            N/A
# 39          N/A      used            N/A
# ...         ...       ...            ...
# 3075  hatchback       new         Fenton
# 4725  hatchback       new         Fenton
# 2744      sedan       new      Englewood
# 3353      sedan       new    Friendswood
# 2568        suv       new  Coral Springs
#
# [6684 rows x 13 columns]

# %% [markdown]
# # Fuel Economy

# %%
path3 = 'clean_fuel_economy.csv'
fuel_ec_df = pd.read_csv(path3)
fuel_ec_df=fuel_ec_df.sort_values(['Year'])
fuel_ec_df
# Out:
#        Year       Make                 Model  City MPG  Highway MPG  \
# 19373  1984  Chevrolet  T10 (S10) Blazer 4WD        15           22
# 19015  1984       Ford     Ranger Pickup 4WD        16           21
# 20083  1984      Dodge     Ram 50 Pickup 2WD        18           23
# 19016  1984       Ford     Ranger Pickup 4WD        18           23
# 19017  1984       Ford     Ranger Pickup 4WD        16           22
# ...     ...        ...                   ...       ...          ...
# 37486  2022       Audi     A4 S line quattro        24           31
# 37487  2022       Audi                    S4        21           30
# 37488  2022   Cadillac                   CT4        23           34
# 37478  2022       Audi      TT Coupe quattro        23           30
# 37535  2022       Audi     A7 TFSI e quattro        25           31
#
#        Combined MPG         Fuel Type  Annual Fuel Cost  \
# 19373            18  Regular Gasoline              2600
# 19015            18  Regular Gasoline              2600
# 20083            20  Regular Gasoline              2350
# 19016            20  Regular Gasoline              2350
# 19017            18  Regular Gasoline              2600
# ...             ...               ...               ...
# 37486            27  Premium Gasoline              2150
# 37487            24  Premium Gasoline              2400
# 37488            27  Premium Gasoline              2150
# 37478            26  Regular Gasoline              1800
# 37535            27  Premium Gasoline              2150
#
#                 Vehicle Size Class  Engine Cylinders       Transmission  \
# 19373  Special Purpose Vehicle 4WD               6.0    Automatic 4-spd
# 19015      Small Pickup Trucks 4WD               4.0       Manual 4-spd
# 20083      Small Pickup Trucks 2WD               4.0       Manual 5-spd
# 19016      Small Pickup Trucks 4WD               4.0       Manual 5-spd
# 19017      Small Pickup Trucks 4WD               4.0       Manual 5-spd
# ...                            ...               ...                ...
# 37486                 Compact Cars               4.0  Automatic (AM-S7)
# 37487                 Compact Cars               6.0     Automatic (S8)
# 37488                 Compact Cars               4.0     Automatic (S8)
# 37478              Subcompact Cars               4.0  Automatic (AM-S7)
# 37535                 Midsize Cars               4.0  Automatic (AM-S7)
#
#                   Drive Axle Type
# 19373  4-Wheel or All-Wheel Drive
# 19015  4-Wheel or All-Wheel Drive
# 20083               2-Wheel Drive
# 19016  4-Wheel or All-Wheel Drive
# 19017  4-Wheel or All-Wheel Drive
# ...                           ...
# 37486             All-Wheel Drive
# 37487               4-Wheel Drive
# 37488            Rear-Wheel Drive
# 37478             All-Wheel Drive
# 37535             All-Wheel Drive
#
# [44040 rows x 12 columns]

# %%
fuel_ec_df['Model']=fuel_ec_df['Model'].str.replace('4WD','').str.replace('2WD','')
fuel_ec_df
# Out:
#        Year       Make              Model  City MPG  Highway MPG  \
# 19373  1984  Chevrolet  T10 (S10) Blazer         15           22
# 19015  1984       Ford     Ranger Pickup         16           21
# 20083  1984      Dodge     Ram 50 Pickup         18           23
# 19016  1984       Ford     Ranger Pickup         18           23
# 19017  1984       Ford     Ranger Pickup         16           22
# ...     ...        ...                ...       ...          ...
# 37486  2022       Audi  A4 S line quattro        24           31
# 37487  2022       Audi                 S4        21           30
# 37488  2022   Cadillac                CT4        23           34
# 37478  2022       Audi   TT Coupe quattro        23           30
# 37535  2022       Audi  A7 TFSI e quattro        25           31
#
#        Combined MPG         Fuel Type  Annual Fuel Cost  \
# 19373            18  Regular Gasoline              2600
# 19015            18  Regular Gasoline              2600
# 20083            20  Regular Gasoline              2350
# 19016            20  Regular Gasoline              2350
# 19017            18  Regular Gasoline              2600
# ...             ...               ...               ...
# 37486            27  Premium Gasoline              2150
# 37487            24  Premium Gasoline              2400
# 37488            27  Premium Gasoline              2150
# 37478            26  Regular Gasoline              1800
# 37535            27  Premium Gasoline              2150
#
#                 Vehicle Size Class  Engine Cylinders       Transmission  \
# 19373  Special Purpose Vehicle 4WD               6.0    Automatic 4-spd
# 19015      Small Pickup Trucks 4WD               4.0       Manual 4-spd
# 20083      Small Pickup Trucks 2WD               4.0       Manual 5-spd
# 19016      Small Pickup Trucks 4WD               4.0       Manual 5-spd
# 19017      Small Pickup Trucks 4WD               4.0       Manual 5-spd
# ...                            ...               ...                ...
# 37486                 Compact Cars               4.0  Automatic (AM-S7)
# 37487                 Compact Cars               6.0     Automatic (S8)
# 37488                 Compact Cars               4.0     Automatic (S8)
# 37478              Subcompact Cars               4.0  Automatic (AM-S7)
# 37535                 Midsize Cars               4.0  Automatic (AM-S7)
#
#                   Drive Axle Type
# 19373  4-Wheel or All-Wheel Drive
# 19015  4-Wheel or All-Wheel Drive
# 20083               2-Wheel Drive
# 19016  4-Wheel or All-Wheel Drive
# 19017  4-Wheel or All-Wheel Drive
# ...                           ...
# 37486             All-Wheel Drive
# 37487               4-Wheel Drive
# 37488            Rear-Wheel Drive
# 37478             All-Wheel Drive
# 37535             All-Wheel Drive
#
# [44040 rows x 12 columns]
