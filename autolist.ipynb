# %%
from bs4 import BeautifulSoup 
import requests
import pandas as pd
import json

# %%
# specify the url
auto_full_details = []
auto_details = []


for page_num in range(1,3447):
    auto_url = 'https://www.autolist.com/search?location=location=Atlanta,%20GA&latitude=33.7489954&longitude=-84.3879824&radius=50&page=' + \
    str(page_num)+'&radius=5000&jumpstart=desktop'
    response = requests.get(auto_url)
    auto_full_details = auto_full_details + json.loads(response.text)['records']


for item in auto_full_details:
    auto_details.append({
      "vin": item["vin"] ,
      "display_color": item["display_color"],
      "year": item["year"],
      "make": item["make"],
      "model": item["model"],
      "price": item["price"],
      "mileage": item["mileage"],
      "city": item["city"],
      "condition": item["condition"],
      "dealer_name": item["dealer_name"],
      "state": item["state"],
      "trim": item["trim"],
      "body_type": item["body_type"],
      "body_style": item["body_style"],
      "monthly_payment": item["monthly_payment"],
      "provider_name": item["provider_name"]     
    })


auto_df = pd.DataFrame(auto_details)

# %%
auto_df
# Out:
#                     vin                       display_color  year       make  \
# 0     WP1AA2A59HLB04454                  Jet Black Metallic  2017    Porsche
# 1     1FTEX1EP1JFB61095                        Shadow Black  2018       Ford
# 2     3GKALPEV8KL250380                 Red Quartz Tintcoat  2019        GMC
# 3     2C3CDZFJ2KH684574                   Sublime Pearlcoat  2019      Dodge
# 4     5FNYF6H0XHB090862                 White Diamond Pearl  2017      Honda
# ...                 ...                                 ...   ...        ...
# 4975  1C4AJWAG5JL854658                                Gray  2018       Jeep
# 4976  1C6SRFJT2MN823734  Granite Crystal Metallic Clearcoat  2021        Ram
# 4977  1G11Z5SA1KU137577               Mosaic Black Metallic  2019  Chevrolet
# 4978  1FM5K8GC1LGA11112                            Magnetic  2020       Ford
# 4979  1HGCV1F18JA042692               Champagne Frost Pearl  2018      Honda
#
#             model    price       mileage          city condition  \
# 0           Macan  $39,499  46,216 Miles         Miami      used
# 1           F-150  $34,999  32,170 Miles         Miami      used
# 2         Terrain  $24,097  48,618 Miles       Spokane      used
# 3      Challenger  $46,299   9,981 Miles       Margate      used
# 4           Pilot  $28,299  69,243 Miles       Margate      used
# ...           ...      ...           ...           ...       ...
# 4975     Wrangler  $34,999  28,738 Miles      Missoula      used
# 4976  Pickup 1500  $57,005           New    Huntsville       new
# 4977       Impala  $21,600  54,839 Miles  Philadelphia      used
# 4978     Explorer  $50,999  21,635 Miles      Stafford      used
# 4979       Accord  $22,299  31,361 Miles     Santa Ana      used
#
#                           dealer_name state           trim body_type  \
# 0             Florida Fine Cars Miami    FL           Base       suv
# 1             Florida Fine Cars Miami    FL            XLT    pickup
# 2              Avis Car Sales Spokane    WA            SLT       suv
# 3         Florida Fine Cars - Margate    FL  R/T Scat Pack     coupe
# 4         Florida Fine Cars - Margate    FL          Elite       suv
# ...                               ...   ...            ...       ...
# 4975  Northwest Motorsport - Missoula    MT          Sport       suv
# 4976  Wischnewsky Dodge Chrysler Jeep    TX        Laramie    pickup
# 4977     Hertz Car Sales Philadelphia    PA             LT     sedan
# 4978                Texas Direct Auto    TX             ST       suv
# 4979        California Motors Direct1    CA             LX     sedan
#
#      body_style  monthly_payment provider_name
# 0           suv         -7116066     car_gurus
# 1         truck         -6305354     car_gurus
# 2           suv         -4341270          avis
# 3         coupe         -8341141     car_gurus
# 4           suv         -5098295     car_gurus
# ...         ...              ...           ...
# 4975        suv         -6305354     car_gurus
# 4976      truck        -10269914     car_gurus
# 4977      sedan         -3891416     car_gurus
# 4978        suv         -9187884         vroom
# 4979      sedan         -4017346     car_gurus
#
# [4980 rows x 16 columns]

# %%
len(auto_df['vin'].unique())
# Out:
# 4980

# %%
clean_auto_df = auto_df.dropna().drop(columns='body_type').drop(columns='monthly_payment').drop(
    columns='index').drop(columns='provider_name').set_index('vin')

# %%
clean_auto_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4857 entries, WP1AA2A59HLB04454 to 1HGCV1F18JA042692
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   display_color  4857 non-null   object
#  1   year           4857 non-null   int64
#  2   make           4857 non-null   object
#  3   model          4857 non-null   object
#  4   price          4857 non-null   object
#  5   mileage        4857 non-null   object
#  6   city           4857 non-null   object
#  7   condition      4857 non-null   object
#  8   dealer_name    4857 non-null   object
#  9   state          4857 non-null   object
#  10  trim           4857 non-null   object
#  11  body_style     4857 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 493.3+ KB

# %%
clean_auto_df
# Out:
#                                         display_color  year       make  \
# vin
# WP1AA2A59HLB04454                  Jet Black Metallic  2017    Porsche
# 1FTEX1EP1JFB61095                        Shadow Black  2018       Ford
# 3GKALPEV8KL250380                 Red Quartz Tintcoat  2019        GMC
# 2C3CDZFJ2KH684574                   Sublime Pearlcoat  2019      Dodge
# 5FNYF6H0XHB090862                 White Diamond Pearl  2017      Honda
# ...                                               ...   ...        ...
# 1C4AJWAG5JL854658                                Gray  2018       Jeep
# 1C6SRFJT2MN823734  Granite Crystal Metallic Clearcoat  2021        Ram
# 1G11Z5SA1KU137577               Mosaic Black Metallic  2019  Chevrolet
# 1FM5K8GC1LGA11112                            Magnetic  2020       Ford
# 1HGCV1F18JA042692               Champagne Frost Pearl  2018      Honda
#
#                          model    price       mileage          city condition  \
# vin
# WP1AA2A59HLB04454        Macan  $39,499  46,216 Miles         Miami      used
# 1FTEX1EP1JFB61095        F-150  $34,999  32,170 Miles         Miami      used
# 3GKALPEV8KL250380      Terrain  $24,097  48,618 Miles       Spokane      used
# 2C3CDZFJ2KH684574   Challenger  $46,299   9,981 Miles       Margate      used
# 5FNYF6H0XHB090862        Pilot  $28,299  69,243 Miles       Margate      used
# ...                        ...      ...           ...           ...       ...
# 1C4AJWAG5JL854658     Wrangler  $34,999  28,738 Miles      Missoula      used
# 1C6SRFJT2MN823734  Pickup 1500  $57,005           New    Huntsville       new
# 1G11Z5SA1KU137577       Impala  $21,600  54,839 Miles  Philadelphia      used
# 1FM5K8GC1LGA11112     Explorer  $50,999  21,635 Miles      Stafford      used
# 1HGCV1F18JA042692       Accord  $22,299  31,361 Miles     Santa Ana      used
#
#                                        dealer_name state           trim  \
# vin
# WP1AA2A59HLB04454          Florida Fine Cars Miami    FL           Base
# 1FTEX1EP1JFB61095          Florida Fine Cars Miami    FL            XLT
# 3GKALPEV8KL250380           Avis Car Sales Spokane    WA            SLT
# 2C3CDZFJ2KH684574      Florida Fine Cars - Margate    FL  R/T Scat Pack
# 5FNYF6H0XHB090862      Florida Fine Cars - Margate    FL          Elite
# ...                                            ...   ...            ...
# 1C4AJWAG5JL854658  Northwest Motorsport - Missoula    MT          Sport
# 1C6SRFJT2MN823734  Wischnewsky Dodge Chrysler Jeep    TX        Laramie
# 1G11Z5SA1KU137577     Hertz Car Sales Philadelphia    PA             LT
# 1FM5K8GC1LGA11112                Texas Direct Auto    TX             ST
# 1HGCV1F18JA042692        California Motors Direct1    CA             LX
#
#                   body_style
# vin
# WP1AA2A59HLB04454        suv
# 1FTEX1EP1JFB61095      truck
# 3GKALPEV8KL250380        suv
# 2C3CDZFJ2KH684574      coupe
# 5FNYF6H0XHB090862        suv
# ...                      ...
# 1C4AJWAG5JL854658        suv
# 1C6SRFJT2MN823734      truck
# 1G11Z5SA1KU137577      sedan
# 1FM5K8GC1LGA11112        suv
# 1HGCV1F18JA042692      sedan
#
# [4857 rows x 12 columns]

# %%
clean_auto_df.to_csv('AutoListData')
