# %%
from bs4 import BeautifulSoup 
import requests
import pandas as pd
import json

# %%
# specify the url
auto_full_details = []
auto_details = []


for page_num in range(1,3447):
    auto_url = 'https://www.autolist.com/search?location=location=Atlanta,%20GA&latitude=33.7489954&longitude=-84.3879824&radius=50&page=' + \
    str(page_num)+'&radius=5000&jumpstart=desktop'
    response = requests.get(auto_url)
    auto_full_details = auto_full_details + json.loads(response.text)['records']


for item in auto_full_details:
    auto_details.append({
      "vin": item["vin"] ,
      "display_color": item["display_color"],
      "year": item["year"],
      "make": item["make"],
      "model": item["model"],
      "price": item["price"],
      "mileage": item["mileage"],
      "city": item["city"],
      "condition": item["condition"],
      "dealer_name": item["dealer_name"],
      "state": item["state"],
      "trim": item["trim"],
      "body_type": item["body_type"],
      "body_style": item["body_style"],
      "monthly_payment": item["monthly_payment"],
      "provider_name": item["provider_name"]     
    })


auto_df = pd.DataFrame(auto_details)

# %%
auto_df
# Out:
#                     vin             display_color  year        make  \
# 0     WP1AA2A59HLB04454        Jet Black Metallic  2017     Porsche
# 1     3FA6P0CD7LR130405      Agate Black Metallic  2020        Ford
# 2     1FTEX1EP1JFB61095              Shadow Black  2018        Ford
# 3     3GKALPEV8KL250380       Red Quartz Tintcoat  2019         GMC
# 4     4S3GKAA68J3615946      Crystal Black Silica  2018      Subaru
# ...                 ...                       ...   ...         ...
# 4975  1C4PJMDX6JD525388                     White  2018        Jeep
# 4976  1FMEE5DPXMLA87711  Carbonized Gray Metallic  2021        Ford
# 4977  3VWG57AU1KM010978                      BLUE  2019  Volkswagen
# 4978  1C6JJTBG5ML579222                       Red  2021        Jeep
# 4979  1FD8W3H61HEC96507                     White  2017        Ford
#
#                  model    price       mileage       city condition  \
# 0                Macan  $39,499  46,216 Miles      Miami      used
# 1               Fusion  $20,299  22,750 Miles    Margate      used
# 2                F-150  $34,999  32,170 Miles      Miami      used
# 3              Terrain  $23,997  48,354 Miles    Spokane      used
# 4              Impreza  $13,999  31,980 Miles      Miami      used
# ...                ...      ...           ...        ...       ...
# 4975          Cherokee  $24,998  40,892 Miles  Maplewood      used
# 4976            Bronco  $49,575           New   Sullivan       new
# 4977              Golf  $28,191   6,610 Miles  Vancouver      used
# 4978         Gladiator  $50,925           New     Ankeny       new
# 4979  F-350 Super Duty  $38,500  99,900 Miles     Searcy      used
#
#                                           dealer_name state  \
# 0                             Florida Fine Cars Miami    FL
# 1                         Florida Fine Cars - Margate    FL
# 2                             Florida Fine Cars Miami    FL
# 3                              Avis Car Sales Spokane    WA
# 4                             Florida Fine Cars Miami    FL
# ...                                               ...   ...
# 4975  CarMax Maplewood - Now offering Curbside Pickup    MN
# 4976                           Laura Ford of Sullivan    MO
# 4977                                 Vancouver Toyota    WA
# 4978                    Dewey Dodge Chrysler Jeep Ram    IA
# 4979                          Creekwood Motor Company    AR
#
#                         trim  body_type body_style  monthly_payment  \
# 0                       Base        suv        suv         -7116066
# 1                        SEL      sedan      sedan         -3657030
# 2                        XLT     pickup      truck         -6305354
# 3                        SLT        suv        suv         -4323255
# 4                       2.0i      sedan      sedan         -2522034
# ...                      ...        ...        ...              ...
# 4975                 Limited        suv        suv         -4503593
# 4976  Black Diamond Advanced        suv        suv         -8931339
# 4977                 1.4T SE  hatchback  hatchback         -5078838
# 4978                 Rubicon     pickup      truck         -9174553
# 4979                     XLT     pickup      truck         -6936088
#
#      provider_name
# 0        car_gurus
# 1        car_gurus
# 2        car_gurus
# 3             avis
# 4        car_gurus
# ...            ...
# 4975        carmax
# 4976     car_gurus
# 4977     car_gurus
# 4978     car_gurus
# 4979     car_gurus
#
# [4980 rows x 16 columns]
